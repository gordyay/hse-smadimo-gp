# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %%
categories=pd.read_csv('datasets/domens_categories.csv')
ranks=pd.read_csv('datasets/ranked_top1000000.csv')
secondary_prices=pd.read_csv('datasets/secondary_prices.csv')

# %% [markdown]
# Датасет с целевой переменной

# %%
ton_domens=pd.read_csv('raw_datasets/ton_domains_history.csv').drop(['tx_hash','sale_type'],axis=1)

# %% [markdown]
# убираем .ton

# %%
ton_domens['domain_name']=ton_domens['domain_name'].map(lambda x: x.split('.')[0])

# %% [markdown]
# Так как это список продаж, один и тот же домен может встречаться несколько раз. Избавляемся от дубликатов, а актуальную цену берём по последней продаже

# %%
ton_domens['tx_time'] = pd.to_datetime(ton_domens['tx_time'], unit='s')
ton_domens.sort_values(by='tx_time', inplace=True)
ton_domens = ton_domens.groupby(by='domain_name', as_index=False).agg(ton_price=('price_ton', 'last'))
ton_domens = ton_domens.rename(columns={'domain_name': 'domain'})

# %% [markdown]
# Собираем итоговый датасет

# %%
ton_dataset = ton_domens.merge(categories, on='domain', how='left')
len(ton_dataset[ton_dataset['category'].notna()])
# Out:
# 3121

# %% [markdown]
# Всего 3121 доменов размеченных по категориям

# %%
ton_dataset=ton_dataset.merge(ranks, on='domain', how='left')

# %%
secondary_prices.rename(columns={'domain_name':'domain'}, inplace=True)
main_dataset = secondary_prices.merge(ton_dataset, on='domain', how='left')
main_dataset
# Out:
#                     domain     price  eth_reg_price  eth_sales_count  \
# 0                 rilxxlir  0.007863          17.22              NaN
# 1                hansberry  0.003712           8.13              NaN
# 2                 lalegend  0.002886           6.32              NaN
# 3              peterwagner  0.001976           4.33              NaN
# 4                stateland  0.000544           1.19              NaN
# ...                    ...       ...            ...              ...
# 3490611  gangster-all-star  0.000481           1.05              NaN
# 3490612        chain-feeds  0.002754           6.03              NaN
# 3490613              68435  0.009944          21.78              1.0
# 3490614   prismai-deployer  0.001257           2.75              NaN
# 3490615                💩🇷🇺  0.065988         144.51              NaN
#
#          eth_sales_volume_usd  eth_last_sale_price_usd  usd_price  \
# 0                         NaN                      NaN  19.387756
# 1                         NaN                      NaN        NaN
# 2                         NaN                      NaN        NaN
# 3                         NaN                      NaN        NaN
# 4                         NaN                      NaN        NaN
# ...                       ...                      ...        ...
# 3490611                   NaN                      NaN        NaN
# 3490612                   NaN                      NaN        NaN
# 3490613              38.41376                 38.41376        NaN
# 3490614                   NaN                      NaN        NaN
# 3490615                   NaN                      NaN        NaN
#
#          sol_sales_count  sol_sales_volume_usd  sol_last_sale_price_usd  \
# 0                    NaN                   NaN                      NaN
# 1                    NaN                   NaN                      NaN
# 2                    NaN                   NaN                      NaN
# 3                    NaN                   NaN                      NaN
# 4                    NaN                   NaN                      NaN
# ...                  ...                   ...                      ...
# 3490611              NaN                   NaN                      NaN
# 3490612              NaN                   NaN                      NaN
# 3490613              NaN                   NaN                      NaN
# 3490614              NaN                   NaN                      NaN
# 3490615              NaN                   NaN                      NaN
#
#          ton_price category  rank
# 0              NaN      NaN   NaN
# 1              NaN      NaN   NaN
# 2              NaN      NaN   NaN
# 3              NaN      NaN   NaN
# 4              NaN      NaN   NaN
# ...            ...      ...   ...
# 3490611        NaN      NaN   NaN
# 3490612        NaN      NaN   NaN
# 3490613        NaN      NaN   NaN
# 3490614        NaN      NaN   NaN
# 3490615        NaN      NaN   NaN
#
# [3490616 rows x 13 columns]

# %%
dataset_with_ton = main_dataset[main_dataset["ton_price"].notna()]
dataset_without_ton = main_dataset[main_dataset["ton_price"].isna()]
dataset_with_ton.to_csv("datasets/dataset_main.csv")
dataset_without_ton.to_csv("datasets/dataset_without_target_value.csv")
dataset_with_ton
# Out:
#                            domain      price  eth_reg_price  eth_sales_count  \
# 59                las-vegas-sands   0.004834          10.59              NaN
# 144             31415926535897932  11.011918       24116.10              NaN
# 169                       sinopec   0.001317           2.88              NaN
# 174                       akulowe   0.001977           4.33              NaN
# 179                          3090   0.038597          84.53              2.0
# ...                           ...        ...            ...              ...
# 3490340           richardbuettner   0.026393          57.80              NaN
# 3490371  themilliondollarhomepage   0.006150          13.47              NaN
# 3490381              metaphysical   0.000622           1.36              1.0
# 3490429                   unicorn   0.013393          29.33              NaN
# 3490489                      redo   0.050818         111.29              1.0
#
#          eth_sales_volume_usd  eth_last_sale_price_usd   usd_price  \
# 59                        NaN                      NaN         NaN
# 144                       NaN                      NaN   20.003004
# 169                       NaN                      NaN   22.000000
# 174                       NaN                      NaN         NaN
# 179                 1980.5715                1378.4700  158.239230
# ...                       ...                      ...         ...
# 3490340                   NaN                      NaN         NaN
# 3490371                   NaN                      NaN   18.974686
# 3490381              214.5822                 214.5822  110.000000
# 3490429                   NaN                      NaN   77.000000
# 3490489              266.2828                 266.2828  150.530090
#
#          sol_sales_count  sol_sales_volume_usd  sol_last_sale_price_usd  \
# 59                   NaN                   NaN                      NaN
# 144                  NaN                   NaN                      NaN
# 169                  NaN                   NaN                      NaN
# 174                  NaN                   NaN                      NaN
# 179                  NaN                   NaN                      NaN
# ...                  ...                   ...                      ...
# 3490340              NaN                   NaN                      NaN
# 3490371              NaN                   NaN                      NaN
# 3490381              NaN                   NaN                      NaN
# 3490429              NaN                   NaN                      NaN
# 3490489              1.0                 300.0                    300.0
#
#          ton_price   category  rank
# 59            1.00        NaN   NaN
# 144           2.01        NaN   NaN
# 169          49.99        NaN   4.0
# 174          30.00        NaN   NaN
# 179         100.00        NaN   NaN
# ...            ...        ...   ...
# 3490340       1.08        NaN   NaN
# 3490371       2.49        NaN   NaN
# 3490381       1.00        NaN   NaN
# 3490429     383.00  Computers   3.0
# 3490489     350.00   Business   NaN
#
# [66995 rows x 13 columns]

# %% [markdown]
# Мы получили два датасета, один с без размеченной целевой переменной, другой без нее. Первый датасет может быть использован для обучения и проверки модели, а второй будет использоваться для отображения потенциальной цены продажи нового домена на сайте webdom.market
